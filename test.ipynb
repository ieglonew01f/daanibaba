# %% [markdown]
# ### Covid-19 Result Set

# %%
# Out:
# <div class="progress-ipython-shell"></div>
# An error was encountered:
# Unexpected character ('/' (code 47)): maybe a (non-standard) comment? (not recognized as one since Feature 'ALLOW_COMMENTS' not enabled for parser)
#  at [Source: /media/ephemeral0/yarn/local/usercache/mukundag/appcache/application_1596529834403_0001/container_1596529834403_0001_01_000001; line: 1, column: 2]

# %%
display(df)
# Out:
# <div class="progress-ipython-shell"></div>
# ...

# %% [markdown]
# ### Confirmed VS Date

# %%
display(df)
# Out:
# <div class="progress-ipython-shell"></div>
# ...

# %% [markdown]
# ### Deaths VS Date

# %%
display(df)
# Out:
# <div class="progress-ipython-shell"></div>
# ...

# %% [markdown]
# ### Death, Recovered vs Date Colored.
# more like grey just like my life

# %%
display(df)
# Out:
# <div class="progress-ipython-shell"></div>
# ...
